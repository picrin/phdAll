# %%
# load the oligo library
library(oligo)

# Read in the CEL files in the directory
exampleCEL = file.path(getwd(), "affy_v4_example.CEL")

celFiles <- list.celfiles(exampleCEL)

list.files()

print(celFiles)

#affyRaw <- read.celfiles(celFiles)

# Load up-to-date annotations for human exon gene microarray.
#library(pd.huex.1.0.st.v2)

# RMA-normalise into `transcription clusters` using the loaded annotations.
#core <- rma(affyRaw, target="core")
#probeset <- rma(affyRaw, target="probeset")
#full <- rma(affyRaw, target="full")
#extended <- rma(affyRaw, target="extended")

# Finally, save the data to an output file to be used by other programs, etc (Data will be log2 transformed and normalized)
#write.exprs(core,file="core")

# In case we decide it's desirable to do so
#write.exprs(probeset,file="probeset")
#write.exprs(full, file="full")
#write.exprs(extended, file="extended")
# Out:
#  [1] "__pycache__"
#  [2] "analyseBlood.sh"
#  [3] "analyseLimma_files"
#  [4] "analyseLimma.aux"
#  [5] "analyseLimma.ipynb"
#  [6] "analyseLimma.log"
#  [7] "analyseLimma.out"
#  [8] "analyseLimma.pdf"
#  [9] "analyseLimma.tex"
# [10] "CELfiles"
# [11] "cleanDatasets.py"
# [12] "cleaned"
# [13] "cleanedLimma"
# [14] "DMBDI genotyping blood DNA Glasgow data with DMBDI ID for John.txt"
# [15] "experiments"
# [16] "ISE"
# [17] "JohnsGenes.csv"
# [18] "krahe"
# [19] "litReview.pdf"
# [20] "MASTERAnonymizedClinicalDataset23Feb2012.txt"
# [21] "masterBlood_files"
# [22] "masterBlood.aux"
# [23] "masterBlood.ipynb"
# [24] "masterBlood.log"
# [25] "masterBlood.out"
# [26] "masterBlood.pdf"
# [27] "masterBlood.tex"
# [28] "microarraySanityCheck.ipynb"
# [29] "normalise.aux"
# [30] "normalise.ipynb"
# [31] "normalise.log"
# [32] "normalise.out"
# [33] "normalise.pdf"
# [34] "normalise.tex"
# [35] "normalised"
# [36] "normalisedFirstLine"
# [37] "normalisedLastLines"
# [38] "overleaf"
# [39] "PGFFiles"
# [40] "produceReport.sh"
# [41] "progressReport.txt"
# [42] "rawProbes.ipynb"
# [43] "setup.R"
# [44] "utils.py"
# [45] "Wilf R file-clean.R"
# [46] "WilfISEs.jpg"
# character(0)
